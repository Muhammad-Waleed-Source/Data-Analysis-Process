# %%
import pandas as pd

# %% [markdown]
# # Importing Files

# %% [markdown]
# ## 1. Working with csv files
#
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %% [markdown]
# ### Opening local csv file

# %%
df = pd.read_csv('Datasets/1-Data-Gathering/aug_train.csv')
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# ### Opening a csv file from an URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ### sep Parameter
# When we want to specify based on which symbol we do separation.

# %%
pd.read_csv('Datasets/1-Data-Gathering/movie_titles_metadata.tsv', sep='\t')

# here we can see that we do not have a column names so for this we have another paramter called names.
# Out:
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# ...

# %% [markdown]
# ### name Parameter

# %%
pd.read_csv('Datasets/1-Data-Gathering/movie_titles_metadata.tsv', sep='\t', names=['sno', 'name', 'release_year', 'rating', 'votes', 'genres'])
# Out:
#       sno                        name release_year  rating     votes  \
# 0      m0  10 things i hate about you         1999     6.9   62847.0
# 1      m1  1492: conquest of paradise         1992     6.2   10421.0
# 2      m2                  15 minutes         2001     6.1   25854.0
# 3      m3       2001: a space odyssey         1968     8.4  163227.0
# 4      m4                     48 hrs.         1982     6.9   22289.0
# ..    ...                         ...          ...     ...       ...
# 612  m612                    watchmen         2009     7.8  135229.0
# 613  m613                         xxx         2002     5.6   53505.0
# 614  m614                       x-men         2000     7.4  122149.0
# 615  m615          young frankenstein         1974     8.0   57618.0
# 616  m616                   zulu dawn         1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# ### index_col Parameter

# %%
pd.read_csv('Datasets/1-Data-Gathering/aug_train.csv', index_col='enrollee_id').head()
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
#
#             enrolled_university education_level major_discipline experience  \
# enrollee_id
# 8949              no_enrollment        Graduate             STEM        >20
# 29725             no_enrollment        Graduate             STEM         15
# 11561          Full time course        Graduate             STEM          5
# 33241                       NaN        Graduate  Business Degree         <1
# 666               no_enrollment         Masters             STEM        >20
#
# ...

# %% [markdown]
# ### header Parameter

# %%
pd.read_csv('Datasets/1-Data-Gathering/test.csv').head()
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
# 2           2        11561    city_21                   0.624        NaN
# 3           3        33241   city_115                   0.789        NaN
# 4           4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# ...

# %%
# here we can see that our column names are treated as a rows, so to make them column names again we use header parameter
pd.read_csv('Datasets/1-Data-Gathering/test.csv', header=1).head()
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %% [markdown]
# ### use_cols Parameter
# When we want to use specific cols while importing

# %%
pd.read_csv('Datasets/1-Data-Gathering/test.csv', header=1, usecols=['enrollee_id', 'gender', 'education_level']).head()
# Out:
#    enrollee_id gender education_level
# 0        29725   Male        Graduate
# 1        11561    NaN        Graduate
# 2        33241    NaN        Graduate
# 3          666   Male         Masters

# %% [markdown]
# ### squeeze Method
# When we want only one columns means it converts the dataframe into a series

# %%
temp = pd.read_csv('Datasets/1-Data-Gathering/aug_train.csv', usecols=['gender']).squeeze()
print(temp)
print(type(temp)) # series
# Out:
# 0        Male
# 1        Male
# 2         NaN
# 3         NaN
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157     NaN
# Name: gender, Length: 19158, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### skiprows/nrows Parameter

# %%
pd.read_csv('Datasets/1-Data-Gathering/aug_train.csv').head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
pd.read_csv('Datasets/1-Data-Gathering/aug_train.csv', skiprows=[0, 1]) # first two rows are skipped
# Out:
#        29725   city_40  0.7759999999999999  Male   No relevent experience  \
# 0      11561   city_21               0.624   NaN   No relevent experience
# 1      33241  city_115               0.789   NaN   No relevent experience
# 2        666  city_162               0.767  Male  Has relevent experience
# 3      21651  city_176               0.764   NaN  Has relevent experience
# 4      28806  city_160               0.920  Male  Has relevent experience
# ...      ...       ...                 ...   ...                      ...
# 19151   7386  city_173               0.878  Male   No relevent experience
# 19152  31398  city_103               0.920  Male  Has relevent experience
# 19153  24576  city_103               0.920  Male  Has relevent experience
# 19154   5756   city_65               0.802  Male  Has relevent experience
# 19155  23834   city_67               0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate             STEM   15    50-99  \
# ...

# %%
# we can also use our own logic inside the skiprows parameter using lambda
pd.read_csv('Datasets/1-Data-Gathering/aug_train.csv', skiprows=lambda x: x % 2 == 0 and x != 0) # for even rows
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0            8949  city_103                   0.920    Male
# 1           11561   city_21                   0.624     NaN
# 2             666  city_162                   0.767    Male
# 3           28806  city_160                   0.920    Male
# 4           27107  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 9574         9212   city_21                   0.624     NaN
# 9575        32313  city_160                   0.920  Female
# 9576        29754  city_103                   0.920  Female
# 9577        31398  city_103                   0.920    Male
# 9578         5756   city_65                   0.802    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience       no_enrollment        Graduate
# 1      No relevent experience    Full time course        Graduate
# ...

# %%
# nrows (Number of rows needed)
pd.read_csv('Datasets/1-Data-Gathering/aug_train.csv', nrows=100)
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %% [markdown]
# ### encoding Parameter
#
# Some CSV files are saved using encodings other than UTF-8 (such as `latin-1`, `ISO-8859-1`, or `cp1252`). In such cases, we use the `encoding` parameter in `pd.read_csv()` to tell pandas how to correctly read the file.

# %%
pd.read_csv('Datasets/1-Data-Gathering/zomato.csv', encoding='latin-1').head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ### on_bad_lines (Skip bad lines)
# A bad line is a row that doesn't match the expected format. For example, if the CSV should have 3 columns, but one row has 4 columns, that row is considered bad.

# %%
pd.read_csv('Datasets/1-Data-Gathering/BX-Books.csv', sep=';', encoding='latin-1', on_bad_lines='skip')
# Out:
#        isbn,book_title,book_author,year_of_publication,publisher
# 0       195153448,Classical Mythology,Mark P. O. Morfo...
# 1       2005018,Clara Callan,Richard Bruce Wright,2001...
# 2       60973129,Decision in Normandy,Carlo D'Este,199...
# 3       374157065,Flu: The Story of the Great Influenz...
# 4       399135782,The Kitchen God's Wife,Amy Tan,1991,...
# ...                                                   ...
# 249950  440400988,There's a Bat in Bunk Five,Paula Dan...
# 249951  525447644,From One to One Hundred,Teri Sloat,1...
# 249952  006008667X,Lily Dale : The True Story of the T...
# 249953  192126040,Republic (World's Classics),Plato,19...
# 249954  767409752,A Guided Tour of Rene Descartes' Med...
#
# [249955 rows x 1 columns]

# %% [markdown]
# ### dtype Parameter

# %%
pd.read_csv('Datasets/1-Data-Gathering/aug_train.csv').head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
# converting the data type of target col
pd.read_csv('Datasets/1-Data-Gathering/aug_train.csv', dtype={'target':int}).head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# ### Handling Dates (parse_dates)

# %%
pd.read_csv('Datasets/1-Data-Gathering/IPL Matches 2008-2020.csv').head()

# here the dates are strings
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
# now to convert them to date we will use parse_date parameter

pd.read_csv('Datasets/1-Data-Gathering/IPL Matches 2008-2020.csv', parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# ### convertors Parameter
# used in file-reading functions like pandas.read_csv that accepts a dictionary mapping column names or indices to custom function

# %%
def rename(name):
    if name == 'Royal Challengers Bangalore':
        return 'RCB'
    else:
        return name

# %%
rename('Royal Challengers Bangalore')
# Out:
# 'RCB'

# %%
pd.read_csv('Datasets/1-Data-Gathering/IPL Matches 2008-2020.csv', converters={'team1': rename}).head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                    team1                        team2  \
# 0                    RCB        Kolkata Knight Riders
# 1        Kings XI Punjab          Chennai Super Kings
# 2       Delhi Daredevils             Rajasthan Royals
# 3         Mumbai Indians  Royal Challengers Bangalore
# ...

# %% [markdown]
# ### na_values Parameter
# to specify additional strings, numbers, or symbols that should be recognized as missing data (NaN)

# %%
# example if we specify the Male as na value

pd.read_csv('Datasets/1-Data-Gathering/aug_train.csv', na_values=['Male']).head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920    NaN
# 1        29725   city_40                   0.776    NaN
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# ### Loading a dataset in chunks

# %%
dfs = pd.read_csv('Datasets/1-Data-Gathering/aug_train.csv', chunksize=5000)
dfs

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)

# %% [markdown]
# ## 2. Import data from excel files

# %%
pd.read_excel('output.xlsx', index_col='Unnamed: 0')

# If excel has two sheets this will automatically fetch the first one

# %% [markdown]
# ### sheet_name Parameter

# %%
# If we want the second one
pd.read_excel('output.xlsx', sheet_name='Sheet_2')

# %% [markdown]
# ### Most of the parameters are same as csv files

# %% [markdown]
# ## 3. Reading text files

# %%
# We will check the structure of text file and see how our data is separated.
pd.read_csv('question_answer_pairs.txt', sep='\t')

# so the separation is based on tabs

# %% [markdown]
# ### Most of the parameters are same as csv files

# %% [markdown]
# ## 4. Reading JSON files

# %%
pd.read_json('Datasets/1-Data-Gathering/train.json').head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %%
# fetching json data from an api
df = pd.read_json("https://jsonplaceholder.typicode.com/users")
df.head()
# Out:
#    id              name   username                      email  \
# 0   1     Leanne Graham       Bret          Sincere@april.biz
# 1   2      Ervin Howell  Antonette          Shanna@melissa.tv
# 2   3  Clementine Bauch   Samantha         Nathan@yesenia.net
# 3   4  Patricia Lebsack   Karianne  Julianne.OConner@kory.org
# 4   5  Chelsey Dietrich     Kamren   Lucio_Hettinger@annie.ca
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
#
#          website                                            company
# ...

# %% [markdown]
# ### Most of the parameters are same as csv files

# %% [markdown]
# ## 5. Reading SQL files
#
# First we have to run our Xampp Server and load our sql data inside a database.

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      - -------------------------------------- 0.5/11.9 MB 1.9 MB/s eta 0:00:06
#      ------ --------------------------------- 1.8/11.9 MB 4.5 MB/s eta 0:00:03
#      -------- ------------------------------- 2.6/11.9 MB 5.0 MB/s eta 0:00:02
#      -------- ------------------------------- 2.6/11.9 MB 5.0 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.4/11.9 MB 3.9 MB/s eta 0:00:03
#      ---------------- ----------------------- 5.0/11.9 MB 4.1 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.2/11.9 MB 3.9 MB/s eta 0:00:02
#      -------------------- ------------------- 6.0/11.9 MB 4.0 MB/s eta 0:00:02
#      ---------------------- ----------------- 6.6/11.9 MB 3.9 MB/s eta 0:00:02
# ...

# %%
import mysql.connector

# %%
conn = msql.connector.connector(host='localhost', user='root', password='', database='world')

# by running this we get a connection object

# %%
pd.read_sql_query('SELECT * FROM city') # (sql query, connection)

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'USA'", conn)

# %%
pd.read_sql_query("SELECT * FROM country", conn)

# %%
pd.read_sql_query("SELECT * FROM country WHERE LifeExpectancy > 60", conn)

# %% [markdown]
# ### Most of the parameters are same as csv files

# %% [markdown]
# # Exporting Files

# %% [markdown]
# ### 1. CSV

# %%
df = pd.read_csv('Datasets/1-Data-Gathering/deliveries.csv')
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
temp_df = df.groupby('batsman')['batsman_runs'].sum().reset_index()

temp_df
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4        A Flintoff            62
# ..              ...           ...
# 456     YV Takawale           192
# 457   Yashpal Singh            47
# 458     Younis Khan             3
# 459    Yuvraj Singh          2591
# 460          Z Khan           117
#
# [461 rows x 2 columns]

# %%
temp_df.to_csv('Datasets/1-Data-Gathering/batsman_runs.csv', index=False)

# %%
temp_df2 = df.pivot_table(index='batsman', columns='bowling_team', values='batsman_runs', aggfunc='sum')
temp_df2
# Out:
# bowling_team    Chennai Super Kings  Deccan Chargers  Delhi Daredevils  \
# batsman
# A Ashish Reddy                 45.0              NaN              36.0
# A Chandila                      NaN              0.0               NaN
# A Chopra                        NaN             35.0              13.0
# A Choudhary                     NaN              NaN               NaN
# A Flintoff                      NaN              NaN              16.0
# ...                             ...              ...               ...
# YV Takawale                    19.0              5.0              14.0
# Yashpal Singh                   NaN              NaN              13.0
# Younis Khan                     NaN              NaN               NaN
# Yuvraj Singh                  321.0            118.0             433.0
# Z Khan                         39.0              4.0               4.0
#
# bowling_team    Gujarat Lions  Kings XI Punjab  Kochi Tuskers Kerala  \
# batsman
# ...

# %%
temp_df2.to_csv('Datasets/1-Data-Gathering/batsman_vs_teams.csv')

# %% [markdown]
# ### 2. Excel

# %%
temp_df
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4        A Flintoff            62
# ..              ...           ...
# 456     YV Takawale           192
# 457   Yashpal Singh            47
# 458     Younis Khan             3
# 459    Yuvraj Singh          2591
# 460          Z Khan           117
#
# [461 rows x 2 columns]

# %%
temp_df2
# Out:
# bowling_team    Chennai Super Kings  Deccan Chargers  Delhi Daredevils  \
# batsman
# A Ashish Reddy                 45.0              NaN              36.0
# A Chandila                      NaN              0.0               NaN
# A Chopra                        NaN             35.0              13.0
# A Choudhary                     NaN              NaN               NaN
# A Flintoff                      NaN              NaN              16.0
# ...                             ...              ...               ...
# YV Takawale                    19.0              5.0              14.0
# Yashpal Singh                   NaN              NaN              13.0
# Younis Khan                     NaN              NaN               NaN
# Yuvraj Singh                  321.0            118.0             433.0
# Z Khan                         39.0              4.0               4.0
#
# bowling_team    Gujarat Lions  Kings XI Punjab  Kochi Tuskers Kerala  \
# batsman
# ...

# %%
temp_df.to_excel('Datasets/1-Data-Gathering/batsman_runs.xlsx')

# %%
# exporting with a sheet name inside an excel file
temp_df.to_excel('Datasets/1-Data-Gathering/output2.xlsx', sheet_name='runs')

# %%
# exporting in multiple sheets inside a single excel file
with pd.ExcelWriter('Datasets/1-Data-Gathering/output.xlsx') as writer:
    temp_df.to_excel(writer, sheet_name='Sheet_name_1')
    temp_df2.to_excel(writer, sheet_name='Sheet_name_2')

# %% [markdown]
# ### 3. HTML

# %%
temp_df3 = df.query('batsman_runs == 6').pivot_table(index='over', columns='ball', values='batsman_runs', aggfunc='count')
temp_df3
# Out:
# ball     1     2     3     4     5     6     7    8    9
# over
# 1      4.0   7.0  17.0  23.0  18.0  18.0  10.0  1.0  NaN
# 2     17.0  17.0  26.0  36.0  30.0  32.0   9.0  4.0  NaN
# 3     44.0  34.0  44.0  38.0  35.0  47.0   5.0  2.0  1.0
# 4     40.0  50.0  39.0  63.0  43.0  43.0   9.0  1.0  NaN
# 5     43.0  47.0  68.0  43.0  49.0  48.0   9.0  2.0  NaN
# 6     51.0  67.0  35.0  47.0  46.0  50.0  10.0  1.0  NaN
# 7     25.0  35.0  21.0  33.0  43.0  22.0   3.0  2.0  NaN
# 8     38.0  40.0  47.0  40.0  46.0  28.0   6.0  NaN  NaN
# 9     57.0  45.0  41.0  46.0  45.0  31.0  11.0  NaN  1.0
# 10    31.0  30.0  43.0  38.0  36.0  45.0   9.0  1.0  NaN
# 11    50.0  55.0  49.0  41.0  51.0  47.0   8.0  NaN  NaN
# 12    55.0  49.0  61.0  55.0  51.0  40.0   6.0  1.0  NaN
# 13    54.0  74.0  47.0  66.0  63.0  55.0   8.0  2.0  NaN
# 14    62.0  64.0  64.0  56.0  52.0  58.0   4.0  2.0  NaN
# 15    52.0  77.0  68.0  66.0  54.0  65.0   7.0  1.0  NaN
# ...

# %%
temp_df3.to_html('Datasets/1-Data-Gathering/sixes_heatmap.html')

# %% [markdown]
# ### 4. JSON

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
temp_df4 = df.groupby(['batting_team', 'batsman'])['batsman_runs'].sum().unstack()
temp_df4
# Out:
# batsman                      A Ashish Reddy  A Chandila  A Chopra  \
# batting_team
# Chennai Super Kings                     NaN         NaN       NaN
# Deccan Chargers                        35.0         NaN       NaN
# Delhi Daredevils                        NaN         NaN       NaN
# Gujarat Lions                           NaN         NaN       NaN
# Kings XI Punjab                         NaN         NaN       NaN
# Kochi Tuskers Kerala                    NaN         NaN       NaN
# Kolkata Knight Riders                   NaN         NaN      53.0
# Mumbai Indians                          NaN         NaN       NaN
# Pune Warriors                           NaN         NaN       NaN
# Rajasthan Royals                        NaN         4.0       NaN
# Rising Pune Supergiant                  NaN         NaN       NaN
# Rising Pune Supergiants                 NaN         NaN       NaN
# Royal Challengers Bangalore             NaN         NaN       NaN
# ...

# %%
temp_df4.to_json('Datasets/1-Data-Gathering/ipl.json')

# %% [markdown]
# ### 5. SQL

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
import pymysql
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:@localhost/')
# {root}:{password}@{url}/{name of the database}
df.to_sql('ipl', con=engine, if_exist='append')

# %%
temp_df
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4        A Flintoff            62
# ..              ...           ...
# 456     YV Takawale           192
# 457   Yashpal Singh            47
# 458     Younis Khan             3
# 459    Yuvraj Singh          2591
# 460          Z Khan           117
#
# [461 rows x 2 columns]

# %%
temp_df.to_sql('batsman_runs', con=engine, if_exist='append')

# %% [markdown]
# # Gather data through API

# %%
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=4062c584cbb627c855d23f42c8f4b358')
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/iCML6fBe3X0y06P33bM7dyYXPKZ.jpg',
#    'genre_ids': [35, 10749],
#    'id': 1632181,
#    'title': 'Accidental Partners',
#    'original_language': 'es',
#    'original_title': 'Socias por accidente',
#    'overview': 'Two women discover they were both scammed by the same man (who also got them pregnant). They form an alliance to take revenge.',
#    'popularity': 31.1991,
#    'poster_path': '/sr1Yoj6XLPTWYcbDoBy67xivW4I.jpg',
#    'release_date': '2026-03-12',
#    'softcore': False,
#    'video': False,
#    'vote_average': 9.0,
#    'vote_count': 318},
#   {'adult': False,
#    'backdrop_path': '/zMwhWailP1WY7sb6AoE6b8ugoy.jpg',
#    'genre_ids': [12, 16, 10751, 14],
#    'id': 1007757,
#    'title': 'Swapped',
#    'original_language': 'en',
#    'original_title': 'Swapped',
# ...

# %%
# so we only need the value of results
movies_list = response.json()['results']
movies_list
# Out:
# [{'adult': False,
#   'backdrop_path': '/iCML6fBe3X0y06P33bM7dyYXPKZ.jpg',
#   'genre_ids': [35, 10749],
#   'id': 1632181,
#   'title': 'Accidental Partners',
#   'original_language': 'es',
#   'original_title': 'Socias por accidente',
#   'overview': 'Two women discover they were both scammed by the same man (who also got them pregnant). They form an alliance to take revenge.',
#   'popularity': 31.1991,
#   'poster_path': '/sr1Yoj6XLPTWYcbDoBy67xivW4I.jpg',
#   'release_date': '2026-03-12',
#   'softcore': False,
#   'video': False,
#   'vote_average': 9.0,
#   'vote_count': 318},
#  {'adult': False,
#   'backdrop_path': '/zMwhWailP1WY7sb6AoE6b8ugoy.jpg',
#   'genre_ids': [12, 16, 10751, 14],
#   'id': 1007757,
#   'title': 'Swapped',
#   'original_language': 'en',
#   'original_title': 'Swapped',
# ...

# %%
top_movies = pd.DataFrame(movies_list)
top_movies.head(2)
# Out:
#    adult                     backdrop_path            genre_ids       id  \
# 0  False  /iCML6fBe3X0y06P33bM7dyYXPKZ.jpg          [35, 10749]  1632181
# 1  False   /zMwhWailP1WY7sb6AoE6b8ugoy.jpg  [12, 16, 10751, 14]  1007757
#
#                  title original_language        original_title  \
# 0  Accidental Partners                es  Socias por accidente
# 1              Swapped                en               Swapped
#
#                                             overview  popularity  \
# 0  Two women discover they were both scammed by t...     31.1991
# 1  A small woodland creature and a majestic bird,...     65.2826
#
#                         poster_path release_date  softcore  video  \
# 0  /sr1Yoj6XLPTWYcbDoBy67xivW4I.jpg   2026-03-12     False  False
# 1  /tHhxWxge06goXU6ZQH1hj7vK8Hd.jpg   2026-05-01     False  False
#
#    vote_average  vote_count
# 0           9.0         318
# 1           8.9        1984

# %%
# Now extracting our desired cols
df = top_movies[['id', 'title', 'release_date', 'overview', 'popularity', 'vote_average', 'vote_count']]
df
# Out:
#          id                                          title release_date  \
# 0   1632181                            Accidental Partners   2026-03-12
# 1   1007757                                        Swapped   2026-05-01
# 2       278                       The Shawshank Redemption   1994-09-23
# 3    936075                                        Michael   2026-04-22
# 4       238                                  The Godfather   1972-03-14
# 5    687163                              Project Hail Mary   2026-03-15
# 6       240                          The Godfather Part II   1974-12-20
# 7       424                               Schindler's List   1993-12-15
# 8       389                                   12 Angry Men   1957-04-10
# 9       129                                  Spirited Away   2001-07-20
# 10      155                                The Dark Knight   2008-07-16
# 11  1330021                    Remarkably Bright Creatures   2026-05-07
# ...

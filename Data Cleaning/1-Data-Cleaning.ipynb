# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Waleed-Source/Data-Analysis-Process/blob/main/Data%20Cleaning/1-Data-Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('smartphones.csv')
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %% [markdown]
# ## Data Assessing
#
# ### Quality Issues
#
# 1. **model** - some brands are written diiferently like OPPO in model column `consistency`
# 2. **price** - has unneccesary '₹' `validity`
# 3. **price** - has ',' between numbers `validity`
# 4. **price** - phone Namotel has a price of 99 `accuracy`
# 5. **ratings** - missing values `completeness`
# 6. **processor** - has some incorrect values for some samsung phones(row # -642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002) `validity`
# 7. There is ipod on row 756 `validity`
# 8. **memory** - incorrect values in rows (441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002) `validity`
# 9. **battery** - incorrect values in rows(113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002) `validity`
# 10. **display** - sometimes frequency is not available `completeness`
# 11. **display** - incorrect values in rows(378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002) `validity`
# 12. certain phones are foldable and the info is scattered `validity`
# 13. **camera** - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'
# 14. **camera** - problem with rows (100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016
# ) `validity`
# 15. **card** - sometimes contains info about os and camera `validity`
# 16. **os** - sometimes contains info about bluetooth and fm radio `validity`
# 17. **os** - issue with rows (324,378) `validity`
# 18. **os** - sometimes contains os version name like lollipop `consistency`
# 19. missing values in camera, card and os `completeness`
# 20. datatype  of price and rating is incorrect `validity`
#
#
#
# ### Tidiness Issues
#
# 1. **sim** - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster
# 2. **ram** - can be split into 2 cols RAM and ROM
# 3. **processor** - can be split into processor name, cores and cpu speed.
# 4. **battery** - can be split into battery capacity, fast_charging_available
# 5. **display** - can be split into size, resolution_width, resolution_height and frequency
# 6. **camera** - can be split into front and rear camera
# 7. **card** - can be split into supported, extended_upto

# %% [markdown]
# ### Let's do programmatic assessment.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %% [markdown]
# We can see that rating, camera, card and os have missing values.
#
# Also some cols have data type issues.

# %%
df.describe()
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Starting with Cleaning

# %% [markdown]
# ### Before cleaning lets make a copy

# %%
df1 = df.copy()
df1
# Out:
#                                 model    price  rating  \
# 0                       OnePlus 11 5G  ₹54,999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2               Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                Motorola Moto G62 5G  ₹14,999    81.0
# 4                  Realme 10 Pro Plus  ₹24,999    82.0
# ...                               ...      ...     ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %% [markdown]
# ### Working with price col

# %%
# Removing the '₹' symbol

df1['price'] = df1['price'].str.replace('₹', '')
df1['price']
# Out:
# 0       54,999
# 1       19,989
# 2       16,499
# 3       14,999
# 4       24,999
#          ...
# 1015    34,990
# 1016    14,990
# 1017    28,990
# 1018    19,990
# 1019    24,990
# Name: price, Length: 1020, dtype: object

# %%
# Now removing the commas
df1['price'] = df1['price'].str.replace(',', '')
df1['price']
# Out:
# 0       54999
# 1       19989
# 2       16499
# 3       14999
# 4       24999
#         ...
# 1015    34990
# 1016    14990
# 1017    28990
# 1018    19990
# 1019    24990
# Name: price, Length: 1020, dtype: object

# %%
# as the price col is a string type so converting it to integer to free some memory

df1['price'] = df1['price'].astype('int')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   int64
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 87.8+ KB

# %% [markdown]
# ### Resetting index

# %%
# resetting the index so that we align with our observations

df1
# Out:
#                                 model  price  rating  \
# 0                       OnePlus 11 5G  54999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2               Samsung Galaxy A14 5G  16499    75.0
# 3                Motorola Moto G62 5G  14999    81.0
# 4                  Realme 10 Pro Plus  24999    82.0
# ...                               ...    ...     ...
# 1015       Motorola Moto Edge S30 Pro  34990    83.0
# 1016                      Honor X8 5G  14990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018             Motorola Moto G91 5G  19990    80.0
# 1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df1 = df1.reset_index()
df1
# Out:
#       index                            model  price  rating  \
# 0         0                    OnePlus 11 5G  54999    89.0
# 1         1        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         2            Samsung Galaxy A14 5G  16499    75.0
# 3         3             Motorola Moto G62 5G  14999    81.0
# 4         4               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1015       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1016                      Honor X8 5G  14990    75.0
# 1017   1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1018             Motorola Moto G91 5G  19990    80.0
# 1019   1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df1['index'] = df1['index'] + 2

# %%
df1

# now the original and copied data start from same index
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
# creating sets for problametic rows

processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))

ram_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))

battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))

display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))

camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ))

# %%
df1[df1['index'].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]

# now we got all the problametic rows
# Out:
#       index                              model   price  rating  \
# 98      100                     Vivo X Fold 5G  106990     NaN
# 111     113                    Apple iPhone 12   51999    74.0
# 149     151               Apple iPhone 12 Mini   40999    74.0
# 155     157                    Nokia 2780 Flip    4990     NaN
# 159     161                    Oppo Find N2 5G   94990     NaN
# ...     ...                                ...     ...     ...
# 954     956  Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988     990                Nokia 5310 Dual Sim    3399     NaN
# 993     995                      Huawei Mate X  169000     NaN
# 1000   1002                    XTouch F40 Flip    1999     NaN
# 1014   1016                      Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]

# rows with common problems
# here we can clearly see that from processor col onwards we have data shifting problem.
# Out:
#       index                   model  price  rating  \
# 640     642          Nokia 105 Plus   1299     NaN
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor  \
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 645          Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# ...

# %%
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]['price'].mean()

# so the problems are with those phones which are cheaper than 3000 rupees (not smartphones)
# Out:
# np.float64(2537.6923076923076)

# %%
# so we will remove these keypad phones.

df1 = df1[df1['price'] >= 3400]

# %%
df1
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera  \
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0
# ...

# %% [markdown]
# ### Fixing processor col

# %%
df1[df1['index'].isin(processor_rows)]

# as these all are feature(keypad) phones so dropping them also
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 857    859             LG Folder 2  11999     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 857       Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 857                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
# ...

# %%
df1.drop([645, 857, 882, 925], inplace=True)
# Out:
# /tmp/ipykernel_560/1088275221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop([645, 857, 882, 925], inplace=True)

# %% [markdown]
# ### Fixing ram col

# %%
df1[df1['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
# 582    584                     Nokia 8210 4G    3749     NaN
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 582                                 Dual Sim, 3G, 4G
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 582                                           No Wifi     Unisoc T107
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
# 582                48 MB RAM, 128 MB inbuilt
#
# ...

# %%
# now 582 index phone is feature phone so also droping it

df1.drop(582, inplace=True)
# Out:
# /tmp/ipykernel_560/4037784671.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(582, inplace=True)

# %%
df1[df1['index'].isin(ram_rows)]

# as we can see that in ram col the ram is not give only the rom is there, so we will hadle this issue while splitting this col into ram and rom
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
#
#                                          display  \
# 439               12 MP Rear & 7 MP Front Camera
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
#
#                                                 camera  \
# ...

# %% [markdown]
# ### Fixing battery col

# %%
df1[df1['index'].isin(battery_rows)]

# as we can see there are two gadgets that are not smartphones i.e index 376 and 754
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 376    378               Nokia 2660 Flip    4649     NaN
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 754    756    Apple iPod Touch (7th Gen)   18900     NaN
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df1.drop([376, 754], inplace=True)
# Out:
# /tmp/ipykernel_560/362795357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop([376, 754], inplace=True)

# %%
temp_df = df1[df1['index'].isin(battery_rows)]
temp_df

# as we can see here there is display information in the battery col, so it is a shifting issue.
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# so right shifting the rows

x = temp_df.iloc[:, 7:].shift(1, axis=1).values

x
# Out:
# array([[None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '4.7 inches, 750\u2009x\u20091334\u2009px Display',
#         '12\u2009MP Rear & 7\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v15'],
# ...

# %%
temp_df.index
# Out:
# Index([111, 149, 307, 363, 439, 448, 628, 762, 853, 913, 914], dtype='int64')

# %%
df1.loc[temp_df.index, temp_df.columns[7:]] = x

# %%
df1[df1['index'].isin(battery_rows)]

# the shifting is now done correctly
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %% [markdown]
# ### Fixing display col

# %%
df1[df1['index'].isin(display_rows)]

# Issue solved already due to earlier shifting of battery rows
# Out:
#      index                         model   price  rating  \
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# ...

# %% [markdown]
# ### Fixing camera col

# %%
df1[df1['index'].isin(camera_rows)]

# as 155, 271 are feature phones so dropping them
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 155     157                           Nokia 2780 Flip    4990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# ...

# %%
df1.drop([155, 271], inplace=True)
# Out:
# /tmp/ipykernel_560/2089369366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop([155, 271], inplace=True)

# %%
df1[df1['index'].isin(camera_rows)]

# so we can see that a camera col with Foldable Display or Dual Display has shift issues.
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# ...

# %%
temp_df = df1[df1['index'].isin(camera_rows)]
temp_df
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# ...

# %%
temp_df[temp_df['camera'].str.contains('MP')]

# so now we have all the rows which have MP, but we need rows which do not have MP.
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 856    858       Samsung Galaxy A01 Core    4999     NaN
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
temp_df = temp_df[~temp_df['camera'].str.contains('MP')]

temp_df

# so these are the rows which contains Foldable Display or Dual Display.
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# 570     572                                LG Wing 5G   54999    89.0
# ...

# %%
# now we want to place the card col values into camera one

df1.loc[temp_df.index, 'camera'] = temp_df['card'].values

# %%
df1[df1['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# ...

# %% [markdown]
# ### Card col has other issues as well, like some rows have operating system, camera values instead of card specs

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB                                       171
# Memory Card Not Supported                                              123
# Android v12                                                            107
# Memory Card Supported, upto 512 GB                                     105
# Memory Card (Hybrid), upto 1 TB                                         91
# Memory Card Supported                                                   89
# Memory Card Supported, upto 256 GB                                      87
# Android v13                                                             46
# Android v11                                                             41
# Memory Card (Hybrid)                                                    30
# Memory Card (Hybrid), upto 256 GB                                       13
# Memory Card (Hybrid), upto 512 GB                                       11
# ...

# %%
# so replacing the rows with camera specs with 'Memory Card not supported"
temp_df = df1[df1['card'].str.contains('MP')]
temp_df
# Out:
#       index                                     model   price  rating  \
# 69       71                          Oppo Find N Fold   99990     NaN
# 98      100                            Vivo X Fold 5G  106990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# ...

# %%
df1.loc[temp_df.index, 'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts()

# as we can see that we replaced the camera details with the Memory Card Not Supported string.
# Out:
# card
# Memory Card Supported, upto 1 TB       171
# Memory Card Not Supported              149
# Android v12                            107
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Android v13                             46
# Android v11                             41
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Android v10                             11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Android v9.0 (Pie)                       2
# Android v12.1                            1
# Memory Card Supported, upto 1000 GB      1
# iOS v10                                  1
# ...

# %%
# So we also have Android values in the card col, so fixing them

temp_df = df1[~df1['card'].str.contains('Memory Card')]
temp_df

# we got all those rows which contains Operating Systems
# Out:
#       index                        model  price  rating  \
# 8        10              Nothing Phone 1  26749    85.0
# 9        11           OnePlus Nord 2T 5G  28999    84.0
# 12       14  Xiaomi Redmi Note 12 Pro 5G  24762    79.0
# 17       19         OPPO Reno 9 Pro Plus  45999    86.0
# 18       20               OnePlus 10R 5G  32999    86.0
# ...     ...                          ...    ...     ...
# 1009   1011                Xiaomi Civi 3  32990    86.0
# 1011   1013                 Oppo Find X6  69990    89.0
# 1012   1014                    itel A23s   4787     NaN
# 1013   1015           Google Pixel 8 Pro  70990    80.0
# 1015   1017   Motorola Moto Edge S30 Pro  34990    83.0
#
#                                                     sim  \
# 8               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 17              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df1.loc[temp_df.index, 'os'] = temp_df['card'].values

# %%
df1.loc[temp_df.index, 'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts() # now we only have memory card info in card col
# Out:
# card
# Memory Card Not Supported              362
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 1000 GB      1
# Memory Card (Hybrid), upto 2 TB          1
# Name: count, dtype: int64

# %% [markdown]
# ### Fixing OS col

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                           394
# Android v11                           274
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     29
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# Android v8.0 (Oreo)                     4
# Android v11.0                           4
# iOS v13                                 4
# iOS v15.0                               3
# Memory Card (Hybrid), upto 2 TB         2
# Memory Card Supported, upto 256 GB      2
# Android v5.1.1 (Lollipop)               2
# Android v12.1                           2
# HarmonyOS v2.0                          2
# iOS v14.0                               2
# EMUI v12                                2
# ...

# %%
temp_df = df1[df1['os'].str.contains('Memory Card')]
temp_df
# Out:
#      index                       model   price  rating  \
# 159    161             Oppo Find N2 5G   94990     NaN
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572                  LG Wing 5G   54999    89.0
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 844    846                CAT S22 Flip   14999     NaN
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                    sim  \
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df1.loc[temp_df.index, 'card'] = df.loc[temp_df.index, 'os']

# replacing the values in card col with the values in os col for those indices only

# %%
df1[df1['os'].str.contains('Memory Card')]
# Out:
#      index                       model   price  rating  \
# 159    161             Oppo Find N2 5G   94990     NaN
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572                  LG Wing 5G   54999    89.0
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 844    846                CAT S22 Flip   14999     NaN
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                    sim  \
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %% [markdown]
# ### Now removing the unnecssary values from the os col, like Memory Card, Bluetooth etc.

# %%
df1.loc[temp_df.index, 'os'] = np.nan

# %%
df1
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
# now removing bluetooth value

df1[df1['os'].str.contains('Bluetooth')] # this gives error because we induced NaN value before, so masking cannot be done on NaN values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_560/3073733065.py in <cell line: 0>()
#       1 # now removing bluetooth value
#       2
# ----> 3 df1[df1['os'].str.contains('Bluetooth')] # this gives error because we induced NaN value before, so masking cannot be done on NaN values
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
# -> 4092         if com.is_bool_indexer(key):
#    4093             return self._getitem_bool_array(key)
#    4094
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     134                     # Don't raise on e.g. ["A", "B", np.nan], see
#     135                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 136                     raise ValueError(na_msg)
# ...

# %%
# so using this approach

temp_df = df1[df1['os'] == 'Bluetooth']
temp_df
# Out:
#      index          model  price  rating                      sim  \
# 486    488  Nokia 8000 4G   6899     NaN  Dual Sim, 3G, 4G, Wi-Fi
#
#                                          processor                       ram  \
# 486  Snapdragon  210, Quad Core, 1.1 GHz Processor  512 MB RAM, 4 GB inbuilt
#
#               battery                           display            camera  \
# 486  1500 mAh Battery  2.8 inches, 240 x 320 px Display  2 MP Rear Camera
#
#                       card         os
# 486  Memory Card Supported  Bluetooth

# %%
df1.loc[temp_df.index, 'os'] = np.nan

# %%
df1['os'].value_counts()

# now we only have operating system related values in os col
# Out:
# os
# Android v12                        394
# Android v11                        274
# Android v13                         91
# Android v10                         69
# Android v9.0 (Pie)                  29
# Android v10.0                       23
# iOS v16                             15
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# iOS v13                              4
# Android v11.0                        4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# Android v12.1                        2
# EMUI v12                             2
# Android v5.1.1 (Lollipop)            2
# HarmonyOS v2.0                       2
# iOS v14.0                            2
# Harmony v2.0                         2
# Android v6.0 (Marshmallow)           2
# Android v5.1 (Lollipop)              1
# Android v4.4.2 (KitKat)              1
# iOS v17                              1
# ...

# %%
df1.shape
# Out:
# (982, 12)

# %%
(982/1020) * 100

# so we removed 4% rows from our data
# Out:
# 96.27450980392157

# %% [markdown]
# ### Most of our data is cleaned now, we can check our cols one by one (manual analysis)

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                        394
# Android v11                        274
# Android v13                         91
# Android v10                         69
# Android v9.0 (Pie)                  29
# Android v10.0                       23
# iOS v16                             15
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# iOS v13                              4
# Android v11.0                        4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# Android v12.1                        2
# EMUI v12                             2
# Android v5.1.1 (Lollipop)            2
# HarmonyOS v2.0                       2
# iOS v14.0                            2
# Harmony v2.0                         2
# Android v6.0 (Marshmallow)           2
# Android v5.1 (Lollipop)              1
# Android v4.4.2 (KitKat)              1
# iOS v17                              1
# ...

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  40
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  38
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                  34
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                            23
# 50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                   20
#                                                                       ..
# 64 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 MP Dual Front Camera     1
# 50 MP + 48 MP + 32 MP Triple Rear & 32 MP Front Camera                 1
# 50 MP + 50 MP + 50 MP Triple Rear & 12 MP Front Camera                 1
# 50 MP + 50 MP + 10 MP Triple Rear & 32 MP Front Camera                 1
# 48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP Front Camera            1
# Name: count, Length: 285, dtype: int64

# %% [markdown]
# # Now making our data tidy

# %%
df1
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %% [markdown]
# ### Fixing model col

# %%
brand_names = df1['model'].str.split(' ').str.get(0)
brand_names
# Out:
# 0        OnePlus
# 1        OnePlus
# 2        Samsung
# 3       Motorola
# 4         Realme
#           ...
# 1015    Motorola
# 1016       Honor
# 1017        POCO
# 1018    Motorola
# 1019     Samsung
# Name: model, Length: 982, dtype: object

# %%
df1.insert(1, 'brand_name', brand_names)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    OnePlus              OnePlus 11 5G  54999    89.0
# 1      3    OnePlus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    Samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   Motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     Realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# ...

# %%
# making all the model names lowercase, in order to avoid inconsistency

df1['brand_name'] = df1['brand_name'].str.lower()
# Out:
# /tmp/ipykernel_560/1380912849.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['brand_name'] = df1['brand_name'].str.lower()

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# ...

# %% [markdown]
# ### Fixing sim col

# %% [markdown]
# Splitting the sim col into three separate cols i.e has_5G, has_NFC and has_IR_Blaster and the other information is same for all phone like Dual sim, Wifi etc.

# %%
has_5g = df1['sim'].str.contains('5G')
has_5g
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1015    True
# 1016    True
# 1017    True
# 1018    True
# 1019    True
# Name: sim, Length: 982, dtype: bool

# %%
has_nfc = df1['sim'].str.contains('NFC')
has_nfc
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1015    False
# 1016    False
# 1017     True
# 1018     True
# 1019    False
# Name: sim, Length: 982, dtype: bool

# %%
has_ir_blaster = df1['sim'].str.contains('IR Blaster')
has_ir_blaster
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1015    False
# 1016    False
# 1017     True
# 1018    False
# 1019    False
# Name: sim, Length: 982, dtype: bool

# %%
df1.insert(6, 'has_5g', has_5g)
df1.insert(7, 'has_nfc', has_nfc)
df1.insert(8, 'has_ir_blaster', has_ir_blaster)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor                        ram  \
# ...

# %% [markdown]
# ### Fixing processor col

# %% [markdown]
# We have three pieces of information here, processor name, number of cores and speed. So splitting the processor col into **processor_name**, **processor_brand**, **processor_cores** and **processor_speed**

# %%
df1['processor'].str.split(',')
# Out:
# 0       [Snapdragon 8 Gen2,  Octa Core,  3.2 GHz Proce...
# 1        [Snapdragon 695,  Octa Core,  2.2 GHz Processor]
# 2           [Exynos 1330,  Octa Core,  2.4 GHz Processor]
# 3       [Snapdragon  695,  Octa Core,  2.2 GHz Processor]
# 4        [Dimensity 1080,  Octa Core,  2.6 GHz Processor]
#                               ...
# 1015    [Snapdragon 8 Gen1,  Octa Core,  3 GHz Processor]
# 1016    [Snapdragon  480+,  Octa Core,  2.2 GHz Proces...
# 1017    [Dimensity 8100,  Octa Core,  2.85 GHz Processor]
# 1018     [Snapdragon 695,  Octa Core,  2.2 GHz Processor]
# 1019                                [Octa Core Processor]
# Name: processor, Length: 982, dtype: object

# %%
processor_name = df1['processor'].str.split(',').str.get(0)
processor_name
# Out:
# 0         Snapdragon 8 Gen2
# 1            Snapdragon 695
# 2               Exynos 1330
# 3           Snapdragon  695
# 4            Dimensity 1080
#                ...
# 1015      Snapdragon 8 Gen1
# 1016       Snapdragon  480+
# 1017         Dimensity 8100
# 1018         Snapdragon 695
# 1019    Octa Core Processor
# Name: processor, Length: 982, dtype: object

# %%
num_cores = df1['processor'].str.split(',').str.get(1)
num_cores
# Out:
# 0        Octa Core
# 1        Octa Core
# 2        Octa Core
# 3        Octa Core
# 4        Octa Core
#            ...
# 1015     Octa Core
# 1016     Octa Core
# 1017     Octa Core
# 1018     Octa Core
# 1019           NaN
# Name: processor, Length: 982, dtype: object

# %%
processor_speed = df1['processor'].str.split(',').str.get(2)
processor_speed
# Out:
# 0         3.2 GHz Processor
# 1         2.2 GHz Processor
# 2         2.4 GHz Processor
# 3         2.2 GHz Processor
# 4         2.6 GHz Processor
#                ...
# 1015        3 GHz Processor
# 1016      2.2 GHz Processor
# 1017     2.85 GHz Processor
# 1018      2.2 GHz Processor
# 1019                    NaN
# Name: processor, Length: 982, dtype: object

# %%
df1.insert(10, 'processor_name', processor_name)
df1.insert(11, 'num_cores', num_cores)
df1.insert(12, 'processor_speed', processor_speed)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# ...

# %% [markdown]
# As we can see in the processor col we almost have three values but in some cases there are two, so by selecting 1 which is actually a 2nd value we are selecting the last value of that col. (Shifting issues)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df1['processor_name'].value_counts())

# we can see here in the processor name col we also have number of core values and we also have white spaces in some values
# Out:
# processor_name
# Dimensity 700 5G           29
# Helio P35                  28
# Snapdragon 8+ Gen1         26
# Snapdragon 8 Gen2          23
# Snapdragon 695             23
# Snapdragon 680             23
# Helio G35                  20
# Snapdragon  680            18
# Snapdragon  8 Gen1         18
# Snapdragon 8 Gen1          17
# Bionic A15                 16
# Snapdragon  695            16
# Dimensity  810 5G          15
# Snapdragon 870             15
# Helio G96                  15
# Helio G80                  14
# Helio G99                  14
# Snapdragon 778G            12
# Dimensity 1080             12
# Snapdragon  8+ Gen1        12
# Dimensity 810 5G           12
# Dimensity  920 5G          11
# Snapdragon 888             11
# Helio G37                  11
# Helio  G85                 10
# Snapdragon  888            10
# Helio A22                  10
# Helio G95                  10
# Bionic  A16                10
# Helio G25                  10
# ...

# %%
# removing white spaces
df1['processor_name'] = df1['processor_name'].str.strip()
# Out:
# /tmp/ipykernel_560/3717773843.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['processor_name'] = df1['processor_name'].str.strip()

# %%
df1[df1['processor_name'].str.contains('Core')]
# Out:
#       index brand_name                                 model  price  rating  \
# 118     120      tesla                        Tesla Pi Phone  69999    83.0
# 143     145        jio                           Jio Phone 3   4499     NaN
# 188     190      ikall                         iKall Z19 Pro   8099    60.0
# 201     203    samsung                    Samsung Galaxy A13  14450    75.0
# 309     311    samsung  Samsung Galaxy A13 (4GB RAM + 128GB)  14999    75.0
# 315     317       itel                          itel S16 Pro   6990     NaN
# 496     498    samsung                    Samsung Galaxy A15  15990    63.0
# 529     531    samsung                    Samsung Galaxy F14  14990    67.0
# 587     589    samsung  Samsung Galaxy A13 (6GB RAM + 128GB)  16499    78.0
# 758     760      ikall                             iKall Z19   7999    61.0
# 778     780      tecno                   Tecno Spark Go 2022   6249    61.0
# ...

# %%
df1[df1['processor_name'].str.contains('Core')][['processor_name', 'num_cores', 'processor_speed']]

# we got the problammatic rows
# Out:
#            processor_name           num_cores processor_speed
# 118   Octa Core Processor                 NaN             NaN
# 143             Quad Core   1.4 GHz Processor             NaN
# 188             Quad Core   1.6 GHz Processor             NaN
# 201             Octa Core     2 GHz Processor             NaN
# 309             Octa Core     2 GHz Processor             NaN
# 315             Quad Core   1.3 GHz Processor             NaN
# 496   Octa Core Processor                 NaN             NaN
# 529   Octa Core Processor                 NaN             NaN
# 587             Octa Core     2 GHz Processor             NaN
# 758             Quad Core   1.6 GHz Processor             NaN
# 778             Octa Core   2.2 GHz Processor             NaN
# 794             Quad Core   1.3 GHz Processor             NaN
# 825   Octa Core Processor                 NaN             NaN
# 826   Octa Core Processor                 NaN             NaN
# ...

# %%
# now shifting them by 1
temp_df = df1[df1['processor_name'].str.contains('Core')][['processor_name', 'num_cores', 'processor_speed']].shift(1, axis=1)

temp_df
# Out:
#      processor_name            num_cores     processor_speed
# 118            None  Octa Core Processor                 NaN
# 143            None            Quad Core   1.4 GHz Processor
# 188            None            Quad Core   1.6 GHz Processor
# 201            None            Octa Core     2 GHz Processor
# 309            None            Octa Core     2 GHz Processor
# 315            None            Quad Core   1.3 GHz Processor
# 496            None  Octa Core Processor                 NaN
# 529            None  Octa Core Processor                 NaN
# 587            None            Octa Core     2 GHz Processor
# 758            None            Quad Core   1.6 GHz Processor
# 778            None            Octa Core   2.2 GHz Processor
# 794            None            Quad Core   1.3 GHz Processor
# 825            None  Octa Core Processor                 NaN
# 826            None  Octa Core Processor                 NaN
# ...

# %%
temp_df.values
# Out:
# array([[None, 'Octa Core Processor', nan],
#        [None, 'Quad Core', ' 1.4\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.6\u2009GHz Processor'],
#        [None, 'Octa Core', ' 2\u2009GHz Processor'],
#        [None, 'Octa Core', ' 2\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.3\u2009GHz Processor'],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core', ' 2\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.6\u2009GHz Processor'],
#        [None, 'Octa Core', ' 2.2\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.3\u2009GHz Processor'],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core', ' 1.8\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.3\u2009GHz Processor'],
# ...

# %%
# now placing the above shifted data into the original dataframe

df1.loc[temp_df.index, ['processor_name', 'num_cores', 'processor_speed']] = temp_df.values

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df1['processor_name'].value_counts())

# now the processor_name col does not contain the number of cores
# Out:
# processor_name
# Helio P35                  30
# Dimensity 700 5G           29
# Snapdragon 695             29
# Snapdragon 8+ Gen1         26
# Snapdragon  695            24
# Snapdragon 680             24
# Snapdragon 8 Gen2          23
# Helio G35                  20
# Snapdragon  680            19
# Snapdragon  8 Gen1         18
# Snapdragon 8 Gen1          18
# Snapdragon 870             16
# Bionic A15                 16
# Helio G96                  15
# Dimensity  810 5G          15
# Helio G99                  14
# Helio G80                  14
# Snapdragon  8+ Gen1        13
# Dimensity 1080             12
# Dimensity 810 5G           12
# Snapdragon  888            12
# Snapdragon 778G            12
# Dimensity  920 5G          11
# Helio G37                  11
# Snapdragon 888             11
# Bionic  A16                10
# Helio A22                  10
# Helio G95                  10
# Helio G25                  10
# Helio  G85                 10
# ...

# %% [markdown]
# We still have one issue in the processor_name col, it contains some weird name (28 nm)

# %%
df1[df1['processor_name'] == '(28 nm)']
# Out:
#      index brand_name                    model  price  rating  \
# 856    858    samsung  Samsung Galaxy A01 Core   4999     NaN
#
#                                 sim  has_5g  has_nfc  has_ir_blaster  \
# 856  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
#
#                                  processor processor_name   num_cores  \
# 856  (28 nm), Quad Core, 1.5 GHz Processor        (28 nm)   Quad Core
#
#         processor_speed                      ram           battery  \
# 856   1.5 GHz Processor  1 GB RAM, 16 GB inbuilt  3000 mAh Battery
#
#                                display                         camera  \
# 856  5.3 inches, 720 x 1480 px Display  8 MP Rear & 5 MP Front Camera
#
#                       card           os
# 856  Memory Card Supported  Android v10

# %%
df1.loc[856, 'processor_name'] = 'Mediatek MT6739'

# %%
df1.loc[856]
# Out:
# index                                                858
# brand_name                                       samsung
# model                            Samsung Galaxy A01 Core
# price                                               4999
# rating                                               NaN
# sim                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# has_5g                                             False
# has_nfc                                            False
# has_ir_blaster                                     False
# processor          (28 nm), Quad Core, 1.5 GHz Processor
# processor_name                           Mediatek MT6739
# num_cores                                      Quad Core
# processor_speed                        1.5 GHz Processor
# ram                              1 GB RAM, 16 GB inbuilt
# battery                                 3000 mAh Battery
# display                5.3 inches, 720 x 1480 px Display
# ...

# %% [markdown]
# Creating another col named processor_brand

# %%
df1['processor_name'].str.split(' ')
# Out:
# 0       [Snapdragon, 8, Gen2]
# 1           [Snapdragon, 695]
# 2              [Exynos, 1330]
# 3         [Snapdragon, , 695]
# 4           [Dimensity, 1080]
#                 ...
# 1015    [Snapdragon, 8, Gen1]
# 1016     [Snapdragon, , 480+]
# 1017        [Dimensity, 8100]
# 1018        [Snapdragon, 695]
# 1019                     None
# Name: processor_name, Length: 982, dtype: object

# %%
processor_brand = df1['processor_name'].str.split(' ').str.get(0).str.lower()

# %%
df1.insert(11, 'processor_brand', processor_brand)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# ...

# %% [markdown]
# ### checking num_cores col now

# %%
df1['num_cores'].value_counts()

# as we can see we have white spaces and also we have multiple entries for the same data with different names
# Out:
# num_cores
#  Octa Core              866
#  Hexa Core               31
#  Quad Core               31
#  Octa Core Processor     19
# Octa Core Processor       9
#  Hexa Core Processor      8
# Quad Core                 6
# Octa Core                 5
# Name: count, dtype: int64

# %%
# removing white spaces

df1['num_cores'] = df1['num_cores'].str.strip()
# Out:
# /tmp/ipykernel_560/2021920998.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['num_cores'] = df1['num_cores'].str.strip()

# %%
df1['num_cores'].value_counts()

# we have multiple entries for the same num_cores with different names, so replacing them
# Out:
# num_cores
# Octa Core              871
# Quad Core               37
# Hexa Core               31
# Octa Core Processor     28
# Hexa Core Processor      8
# Name: count, dtype: int64

# %%
df1['num_cores'] = df1['num_cores'].str.replace('Octa Core Processor', 'Octa Core')
# Out:
# /tmp/ipykernel_560/1393635790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['num_cores'] = df1['num_cores'].str.replace('Octa Core Processor', 'Octa Core')

# %%
df1['num_cores'] = df1['num_cores'].str.replace('Hexa Core Processor', 'Hexa Core')
# Out:
# /tmp/ipykernel_560/713792657.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['num_cores'] = df1['num_cores'].str.replace('Hexa Core Processor', 'Hexa Core')

# %%
df1['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core    899
# Hexa Core     39
# Quad Core     37
# Name: count, dtype: int64

# %% [markdown]
# ### checking processor_speed col now

# %%
df1['processor_speed'].value_counts()

# we do not have issue with the data, but we all know the speed unit is same for all, just converting these values to integer by removing GHz
# Out:
# processor_speed
# 2 GHz Processor       146
# 2.2 GHz Processor     135
# 2.4 GHz Processor     128
# 3.2 GHz Processor      94
# 2.3 GHz Processor      86
# 3 GHz Processor        53
# 2.84 GHz Processor     36
# 2.05 GHz Processor     28
# 1.8 GHz Processor      23
# 2.5 GHz Processor      23
# 1.6 GHz Processor      20
# 2.85 GHz Processor     19
# 3.22 GHz Processor     18
# 3.1 GHz Processor      15
# 2.6 GHz Processor      14
# 2.9 GHz Processor      13
# 1.3 GHz Processor      10
# 1.82 GHz Processor     10
# 2.73 GHz Processor      9
# 2.8 GHz Processor       9
# 2.36 GHz Processor      8
# 3.05 GHz Processor      8
# 1.4 GHz Processor       5
# 2.65 GHz Processor      5
# 2.7 GHz Processor       5
# 1.5 GHz Processor       4
# 2.96 GHz Processor      3
# 2.86 GHz Processor      3
# 3.13 GHz Processor      2
# 1.1 GHz Processor       1
# 2.37 GHz Processor      1
# 2.35 GHz Processor      1
# 1.99 GHz Processor      1
# 1.95 GHz Processor      1
# 2.1 GHz Processor       1
# ...

# %%
df1['processor_speed'].str.strip().str.split(' ')
# Out:
# 0        [3.2 GHz, Processor]
# 1        [2.2 GHz, Processor]
# 2        [2.4 GHz, Processor]
# 3        [2.2 GHz, Processor]
# 4        [2.6 GHz, Processor]
#                 ...
# 1015       [3 GHz, Processor]
# 1016     [2.2 GHz, Processor]
# 1017    [2.85 GHz, Processor]
# 1018     [2.2 GHz, Processor]
# 1019                      NaN
# Name: processor_speed, Length: 982, dtype: object

# %%
# the speed value and unit are still together, they are not split by a space because they used a thin space unicode character

df1['processor_speed'].str.strip().str.split(' ').str.get(0)[0]
# Out:
# '3.2\u2009GHz'

# %%
# so replacing it with a proper space

df1['processor_speed'].str.strip().str.split(' ').str.get(0).str.replace('\u2009', ' ')
# Out:
# 0        3.2 GHz
# 1        2.2 GHz
# 2        2.4 GHz
# 3        2.2 GHz
# 4        2.6 GHz
#           ...
# 1015       3 GHz
# 1016     2.2 GHz
# 1017    2.85 GHz
# 1018     2.2 GHz
# 1019         NaN
# Name: processor_speed, Length: 982, dtype: object

# %%
# now splitting on top of space

df1['processor_speed'].str.strip().str.split(' ').str.get(0).str.replace('\u2009', ' ').str.split(' ')
# Out:
# 0        [3.2, GHz]
# 1        [2.2, GHz]
# 2        [2.4, GHz]
# 3        [2.2, GHz]
# 4        [2.6, GHz]
#            ...
# 1015       [3, GHz]
# 1016     [2.2, GHz]
# 1017    [2.85, GHz]
# 1018     [2.2, GHz]
# 1019            NaN
# Name: processor_speed, Length: 982, dtype: object

# %%
# getting the first value

df1['processor_speed'] = df1['processor_speed'].str.strip().str.split(' ').str.get(0).str.replace('\u2009', ' ').str.split(' ').str.get(0).astype(float)
# Out:
# /tmp/ipykernel_560/2877786326.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['processor_speed'] = df1['processor_speed'].str.strip().str.split(' ').str.get(0).str.replace('\u2009', ' ').str.split(' ').str.get(0).astype(float)

# %%
df1['processor_speed']
# Out:
# 0       3.20
# 1       2.20
# 2       2.40
# 3       2.20
# 4       2.60
#         ...
# 1015    3.00
# 1016    2.20
# 1017    2.85
# 1018    2.20
# 1019     NaN
# Name: processor_speed, Length: 982, dtype: float64

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# ...

# %% [markdown]
# ### Fixing ram col

# %%
df1['ram']

# here we can see we have ram and as well as storage in the same col, so splitting it
# Out:
# 0       12 GB RAM, 256 GB inbuilt
# 1        6 GB RAM, 128 GB inbuilt
# 2         4 GB RAM, 64 GB inbuilt
# 3        6 GB RAM, 128 GB inbuilt
# 4        6 GB RAM, 128 GB inbuilt
#                   ...
# 1015     8 GB RAM, 128 GB inbuilt
# 1016     6 GB RAM, 128 GB inbuilt
# 1017     8 GB RAM, 256 GB inbuilt
# 1018     6 GB RAM, 128 GB inbuilt
# 1019     8 GB RAM, 128 GB inbuilt
# Name: ram, Length: 982, dtype: object

# %%
df1['ram'].str.strip().str.split(',')
# Out:
# 0       [12 GB RAM,  256 GB inbuilt]
# 1        [6 GB RAM,  128 GB inbuilt]
# 2         [4 GB RAM,  64 GB inbuilt]
# 3        [6 GB RAM,  128 GB inbuilt]
# 4        [6 GB RAM,  128 GB inbuilt]
#                     ...
# 1015     [8 GB RAM,  128 GB inbuilt]
# 1016     [6 GB RAM,  128 GB inbuilt]
# 1017     [8 GB RAM,  256 GB inbuilt]
# 1018     [6 GB RAM,  128 GB inbuilt]
# 1019     [8 GB RAM,  128 GB inbuilt]
# Name: ram, Length: 982, dtype: object

# %%
df1['ram'].str.strip().str.split(',').str.get(0).str.split(' ')

# thin unicode space between number and GB
# Out:
# 0       [12 GB, RAM]
# 1        [6 GB, RAM]
# 2        [4 GB, RAM]
# 3        [6 GB, RAM]
# 4        [6 GB, RAM]
#             ...
# 1015     [8 GB, RAM]
# 1016     [6 GB, RAM]
# 1017     [8 GB, RAM]
# 1018     [6 GB, RAM]
# 1019     [8 GB, RAM]
# Name: ram, Length: 982, dtype: object

# %%
ram_capacity = df1['ram'].str.strip().str.split(',').str.get(0).str.findall(r'\b(\d+)\b').str.get(0)

ram_capacity
# so we used regex this time to extract the integer values
# Out:
# 0       12
# 1        6
# 2        4
# 3        6
# 4        6
#         ..
# 1015     8
# 1016     6
# 1017     8
# 1018     6
# 1019     8
# Name: ram, Length: 982, dtype: object

# %%
df1.insert(16, 'ram_capacity', ram_capacity)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... processor_brand  \
# ...

# %%
internal_memory = df1['ram'].str.strip().str.split(',').str.get(1).str.strip()

internal_memory
# Out:
# 0       256 GB inbuilt
# 1       128 GB inbuilt
# 2        64 GB inbuilt
# 3       128 GB inbuilt
# 4       128 GB inbuilt
#              ...
# 1015    128 GB inbuilt
# 1016    128 GB inbuilt
# 1017    256 GB inbuilt
# 1018    128 GB inbuilt
# 1019    128 GB inbuilt
# Name: ram, Length: 982, dtype: object

# %%
internal_memory[0]

# here also the thin unicode space is used
# Out:
# '256\u2009GB inbuilt'

# %%
internal_memory = df1['ram'].str.strip().str.split(',').str.get(1).str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.insert(17, 'internal_memory', internal_memory)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ...  num_cores  \
# ...

# %% [markdown]
# ### ram_capacity col has some issues, some phone contain 18, 256 and 512 gb rams.

# %%
# first converting the ram_capacity into number as it is string

df1['ram_capacity'] = df1['ram_capacity'].astype(float)
# Out:
# /tmp/ipykernel_560/3299246261.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['ram_capacity'] = df1['ram_capacity'].astype(float)

# %%
df1[df1['ram_capacity'] > 18]

# as we can see here at index 439 and 762 there is a shifting problem inbuilt memory is shifted to ram_capacity col. Also we have problems in 483, 486 and 627 because the memories are in MBs not GBs
# Out:
#      index brand_name                             model   price  rating  \
# 439    441      apple            Apple iPhone SE 3 2022   43900     NaN
# 483    485     huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 486    488      nokia                     Nokia 8000 4G    6899     NaN
# 627    629      nokia                      Nokia 225 4G    3589     NaN
# 762    764      apple                 Apple iPhone SE 4   49990    60.0
#
#                                                  sim  has_5g  has_nfc  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster   False     True
# 486                          Dual Sim, 3G, 4G, Wi-Fi   False    False
# 627                          Dual Sim, 3G, 4G, VoLTE   False    False
# 762          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
#
#      has_ir_blaster                                         processor  ...  \
# ...

# %% [markdown]
# Fixing shifting issue (439 and 762)

# %%
df1.loc[[439, 762], ['ram_capacity']] = [4.0, 4.0]

# %%
df1[df1['ram_capacity'] > 18]
# Out:
#      index brand_name                             model   price  rating  \
# 483    485     huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 486    488      nokia                     Nokia 8000 4G    6899     NaN
# 627    629      nokia                      Nokia 225 4G    3589     NaN
#
#                                                  sim  has_5g  has_nfc  \
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster   False     True
# 486                          Dual Sim, 3G, 4G, Wi-Fi   False    False
# 627                          Dual Sim, 3G, 4G, VoLTE   False    False
#
#      has_ir_blaster                                         processor  ...  \
# 483            True  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  ...
# 486           False     Snapdragon  210, Quad Core, 1.1 GHz Processor  ...
# 627           False                                       Unisoc T117  ...
#
#      num_cores processor_speed                        ram  \
# ...

# %% [markdown]
# now we have these three rows with issues, that the ram capacities are in MBs

# %%
df1.loc[483, ['ram_capacity', 'internal_memory']] = [12.0, '512']

# %%
df1[df1['ram_capacity'] > 18]
# Out:
#      index brand_name          model  price  rating                      sim  \
# 486    488      nokia  Nokia 8000 4G   6899     NaN  Dual Sim, 3G, 4G, Wi-Fi
# 627    629      nokia   Nokia 225 4G   3589     NaN  Dual Sim, 3G, 4G, VoLTE
#
#      has_5g  has_nfc  has_ir_blaster  \
# 486   False    False           False
# 627   False    False           False
#
#                                          processor  ...  num_cores  \
# 486  Snapdragon  210, Quad Core, 1.1 GHz Processor  ...  Quad Core
# 627                                    Unisoc T117  ...        NaN
#
#     processor_speed                        ram           battery ram_capacity  \
# 486             1.1   512 MB RAM, 4 GB inbuilt  1500 mAh Battery        512.0
# 627             NaN  64 MB RAM, 128 MB inbuilt  1150 mAh Battery         64.0
#
#     internal_memory                           display              camera  \
# 486               4  2.8 inches, 240 x 320 px Display    2 MP Rear Camera
# ...

# %% [markdown]
# as the above two remaining rows are feature phone so dropping them

# %%
df1.drop([486, 627], inplace=True)
# Out:
# /tmp/ipykernel_560/2405428601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop([486, 627], inplace=True)

# %%
df1['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8.0     339
# 6.0     234
# 4.0     217
# 12.0     86
# 3.0      54
# 2.0      32
# 16.0      9
# 1.0       7
# 18.0      2
# Name: count, dtype: int64

# %% [markdown]
# ### Fixing internal_memory col

# %%
df1['internal_memory'].value_counts()

# the 1 here is TB not GB.
# Out:
# internal_memory
# 128    523
# 64     191
# 256    157
# 32      67
# 512     22
# 16      12
# 1        5
# 8        1
# Name: count, dtype: int64

# %%
# converting data type to float
df1['internal_memory'] = df1['internal_memory'].astype(float)
# Out:
# /tmp/ipykernel_560/703314744.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['internal_memory'] = df1['internal_memory'].astype(float)

# %%
df1[df1['internal_memory'] < 32]
# Out:
#      index brand_name                                     model   price  \
# 290    292      apple             Apple iPhone 14 Pro Max (1TB)  182999
# 399    401       itel                                  itel P36    6490
# 477    479       vivo                                  Vivo Y25    7499
# 574    576       vivo                                  Vivo Y71   25000
# 735    737      tecno                            Tecno Pop 5 Go    6999
# 738    740      nokia                            Nokia C01 Plus    5249
# 744    746       itel                                  itel S16    5990
# 781    783      apple             Apple iPhone 13 Pro Max (1TB)  179900
# 794    796       itel                                  itel A56    5490
# 814    816      apple                 Apple iPhone 14 Pro (1TB)  172999
# 844    846        cat                              CAT S22 Flip   14999
# 856    858    samsung                   Samsung Galaxy A01 Core    4999
# ...

# %%
# above we can see that the problametic rows are with value 1 which is 1 TB not 1 GB, so we will write 1024 Gbs instead of 1 TB

temp_df = df1[df1['internal_memory'] == 1]
temp_df
# Out:
#      index brand_name                                     model   price  \
# 290    292      apple             Apple iPhone 14 Pro Max (1TB)  182999
# 781    783      apple             Apple iPhone 13 Pro Max (1TB)  179900
# 814    816      apple                 Apple iPhone 14 Pro (1TB)  172999
# 943    945    samsung  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980
# 961    963      apple                 Apple iPhone 13 Pro (1TB)  147900
#
#      rating                                      sim  has_5g  has_nfc  \
# 290    78.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 781    86.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 814    77.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 943     NaN  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 961    84.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
#
#      has_ir_blaster                                          processor  ...  \
# ...

# %%
df1.loc[temp_df.index, 'internal_memory'] = 1024

# %%
df1[df1['internal_memory'] == 1]
# Out:
# Empty DataFrame
# Columns: [index, brand_name, model, price, rating, sim, has_5g, has_nfc, has_ir_blaster, processor, processor_name, processor_brand, num_cores, processor_speed, ram, battery, ram_capacity, internal_memory, display, camera, card, os]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### Fixing the battery col

# %% [markdown]
# battery col has two pieces of information i.e capacity and fast charging support. So creating two cols from this.

# %%
df1['battery'].str.strip().str.split('with')
# Out:
# 0        [5000 mAh Battery ,  100W Fast Charging]
# 1         [5000 mAh Battery ,  33W Fast Charging]
# 2         [5000 mAh Battery ,  15W Fast Charging]
# 3             [5000 mAh Battery ,  Fast Charging]
# 4         [5000 mAh Battery ,  67W Fast Charging]
#                           ...
# 1015    [5000 mAh Battery ,  68.2W Fast Charging]
# 1016    [5000 mAh Battery ,  22.5W Fast Charging]
# 1017      [5080 mAh Battery ,  67W Fast Charging]
# 1018          [5000 mAh Battery ,  Fast Charging]
# 1019          [5000 mAh Battery ,  Fast Charging]
# Name: battery, Length: 980, dtype: object

# %%
df1['battery'].str.strip().str.split('with').str.get(0).str.strip().str.split(' ')
# Out:
# 0       [5000 mAh, Battery]
# 1       [5000 mAh, Battery]
# 2       [5000 mAh, Battery]
# 3       [5000 mAh, Battery]
# 4       [5000 mAh, Battery]
#                ...
# 1015    [5000 mAh, Battery]
# 1016    [5000 mAh, Battery]
# 1017    [5080 mAh, Battery]
# 1018    [5000 mAh, Battery]
# 1019    [5000 mAh, Battery]
# Name: battery, Length: 980, dtype: object

# %%
# extracting numbers from it

battery_capacity = df1['battery'].str.strip().str.split('with').str.get(0).str.strip().str.findall(r'\b(\d+)\b').str.get(0).astype(float)

battery_capacity
# Out:
# 0       5000.0
# 1       5000.0
# 2       5000.0
# 3       5000.0
# 4       5000.0
#          ...
# 1015    5000.0
# 1016    5000.0
# 1017    5080.0
# 1018    5000.0
# 1019    5000.0
# Name: battery, Length: 980, dtype: float64

# %%
df1.insert(16, 'battery_capacity', battery_capacity)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... processor_speed  \
# ...

# %%
# now creating a new col fast charging support

fast_charging = df1['battery'].str.strip().str.split('with').str.get(1).str.strip().str.findall(r'(\d+)')

fast_charging

# now we got the watts at which it is fast charged
# Out:
# 0         [100]
# 1          [33]
# 2          [15]
# 3            []
# 4          [67]
#          ...
# 1015    [68, 2]
# 1016    [22, 5]
# 1017       [67]
# 1018         []
# 1019         []
# Name: battery, Length: 980, dtype: object

# %%
df1.insert(17, 'fast_charging', fast_charging)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ...  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...
# ...

# %%
df1['fast_charging'].value_counts()

# as we can see here that we have some phones with fastcharging support but the watt is not mentioned, it is marked as [].
# Out:
# fast_charging
# [33]       152
# [18]       128
# []          68
# [67]        65
# [25]        53
# [120]       46
# [15]        43
# [80]        42
# [66]        37
# [10]        33
# [30]        32
# [65]        30
# [44]        23
# [45]        17
# [20]        10
# [100]        7
# [68]         7
# [150]        7
# [125]        6
# [40]         5
# [22, 5]      5
# [60]         4
# [55]         3
# [210]        2
# [50]         2
# [21]         2
# [240]        1
# [200]        1
# [180]        1
# [19]         1
# [165]        1
# [135]        1
# [27]         1
# [68, 2]      1
# Name: count, dtype: int64

# %%
# so creating a function for this

def fast_charging_extractor(item):

  if type(item) == list:
    if len(item) == 1:
      return item[0]
    else:
      return 0
  else:
    return -1

# 0 = has fast charging but watt is not known
# -1 = has not fast charging

# %%
df1['fast_charging'].apply(fast_charging_extractor).astype(int)
# Out:
# 0       100
# 1        33
# 2        15
# 3         0
# 4        67
#        ...
# 1015      0
# 1016      0
# 1017     67
# 1018      0
# 1019      0
# Name: fast_charging, Length: 980, dtype: int64

# %%
df1['fast_charging'] = df1['fast_charging'].apply(fast_charging_extractor).astype(int)
# Out:
# /tmp/ipykernel_560/3894870647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['fast_charging'] = df1['fast_charging'].apply(fast_charging_extractor).astype(int)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ...  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...
# ...

# %% [markdown]
# ### Fixing display col

# %% [markdown]
# In the display col we have three pieces of information, screen size, resolution and refresh rate.

# %%
df1['display'].str.strip().str.split(',')
# Out:
# 0       [6.7 inches,  1440 x 3216 px,  120 Hz Display ...
# 1       [6.59 inches,  1080 x 2412 px,  120 Hz Display...
# 2       [6.6 inches,  1080 x 2408 px,  90 Hz Display w...
# 3       [6.55 inches,  1080 x 2400 px,  120 Hz Display...
# 4       [6.7 inches,  1080 x 2412 px,  120 Hz Display ...
#                               ...
# 1015    [6.67 inches,  1080 x 2460 px,  120 Hz Display...
# 1016    [6.5 inches,  720 x 1600 px Display with Water...
# 1017    [6.6 inches,  1080 x 2460 px,  144 Hz Display ...
# 1018    [6.8 inches,  1080 x 2400 px Display with Punc...
# 1019    [6.5 inches,  1080 x 2400 px Display with Wate...
# Name: display, Length: 980, dtype: object

# %%
# extracting screen size

screen_size = df1['display'].str.strip().str.split(',').str.get(0).str.strip().str.split(' ').str.get(0).astype(float)

screen_size
# Out:
# 0       6.70
# 1       6.59
# 2       6.60
# 3       6.55
# 4       6.70
#         ...
# 1015    6.67
# 1016    6.50
# 1017    6.60
# 1018    6.80
# 1019    6.50
# Name: display, Length: 980, dtype: float64

# %%
df1.insert(21, 'screen_size', screen_size)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ...  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...
# ...

# %%
# extracting screen resolution

resolution = df1['display'].str.strip().str.split(',').str.get(1).str.strip().str.split('px').str.get(0)

resolution
# Out:
# 0       1440 x 3216
# 1       1080 x 2412
# 2       1080 x 2408
# 3       1080 x 2400
# 4       1080 x 2412
#             ...
# 1015    1080 x 2460
# 1016     720 x 1600
# 1017    1080 x 2460
# 1018    1080 x 2400
# 1019    1080 x 2400
# Name: display, Length: 980, dtype: object

# %%
df1.insert(22, 'resolution', resolution)

# %%
df1.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... battery_capacity  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...           5000.0
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...           5000.0
#
#   fast_charging ram_capacity  internal_memory  \
# 0           100         12.0            256.0
# 1            33          6.0            128.0
#
#                                              display screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...        6.70
# ...

# %%
# extracting screen refresh rate

df1['display'].str.strip().str.split(',').str.get(2).str.strip().str.split('Hz').str.get(0)
# Out:
# 0       120
# 1       120
# 2        90
# 3       120
# 4       120
#         ...
# 1015    120
# 1016     NaN
# 1017    144
# 1018     NaN
# 1019     NaN
# Name: display, Length: 980, dtype: object

# %%
# as above there are NaN values, so according to the industry standards the refresh rate is 60 Hz, so populating NaN with 60.

refresh_rate = df1['display'].str.strip().str.split(',').str.get(2).str.strip().str.split('Hz').str.get(0).apply(lambda x:60 if pd.isna(x) else x).astype(int)

refresh_rate
# Out:
# 0       120
# 1       120
# 2        90
# 3       120
# 4       120
#        ...
# 1015    120
# 1016     60
# 1017    144
# 1018     60
# 1019     60
# Name: display, Length: 980, dtype: int64

# %%
df1.insert(23, 'refresh_rate', refresh_rate)

# %%
df1.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... fast_charging  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...           100
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...            33
#
#   ram_capacity internal_memory  \
# 0         12.0           256.0
# 1          6.0           128.0
#
#                                              display screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...        6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...        6.59
#
# ...

# %% [markdown]
# ### Fixing the camera col

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
    print(df1['camera'].value_counts())

# assessing the data
# Out:
# camera
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   40
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   38
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                   34
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                             23
# 13 MP Rear & 5 MP Front Camera                                         20
# 50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                    20
# 12 MP + 12 MP Dual Rear & 12 MP Front Camera                           20
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                             19
# 8 MP Rear & 5 MP Front Camera                                          19
# 108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  18
# 13 MP + 2 MP Dual Rear & 8 MP Front Camera                             18
# 64 MP Quad Rear & 32 MP Front Camera                                   18
# 64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                   16
# ...

# %% [markdown]
# We can make four cols, number of rear cameras, number of front cameras, primary rear lens megapixel, primary front lens megapixel

# %%
df1['camera'].str.strip().str.split('&')
# Out:
# 0       [50 MP + 48 MP + 32 MP Triple Rear ,  16 MP Fr...
# 1       [64 MP + 2 MP + 2 MP Triple Rear ,  16 MP Fron...
# 2       [50 MP + 2 MP + 2 MP Triple Rear ,  13 MP Fron...
# 3       [50 MP + 8 MP + 2 MP Triple Rear ,  16 MP Fron...
# 4       [108 MP + 8 MP + 2 MP Triple Rear ,  16 MP Fro...
#                               ...
# 1015    [64 MP + 8 MP + 2 MP Triple Rear ,  16 MP Fron...
# 1016    [48 MP + 2 MP + Depth Sensor Triple Rear ,  8 ...
# 1017    [64 MP + 8 MP + 2 MP Triple Rear ,  16 MP Fron...
# 1018    [108 MP + 8 MP + 2 MP Triple Rear ,  32 MP Fro...
# 1019    [64 MP + 8 MP + 5 MP Triple Rear ,  32 MP Fron...
# Name: camera, Length: 980, dtype: object

# %%
df1['camera'].str.strip().str.split('&').str.get(0)
# Out:
# 0             50 MP + 48 MP + 32 MP Triple Rear
# 1               64 MP + 2 MP + 2 MP Triple Rear
# 2               50 MP + 2 MP + 2 MP Triple Rear
# 3               50 MP + 8 MP + 2 MP Triple Rear
# 4              108 MP + 8 MP + 2 MP Triple Rear
#                           ...
# 1015            64 MP + 8 MP + 2 MP Triple Rear
# 1016    48 MP + 2 MP + Depth Sensor Triple Rear
# 1017            64 MP + 8 MP + 2 MP Triple Rear
# 1018           108 MP + 8 MP + 2 MP Triple Rear
# 1019            64 MP + 8 MP + 5 MP Triple Rear
# Name: camera, Length: 980, dtype: object
